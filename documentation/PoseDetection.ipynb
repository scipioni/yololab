# %% [markdown]
# Yolov8n-POSE:
#
# Pose model output is an array of size 57, 17 keypoints with x,y coordinates at three scales
#
# 17 keypoints:
# - 5 spine
# - 4 left arm
# - 4 right arm
# - 2 left leg
# - 2 right leg
#
#
# ![image.png](attachment:image.png)
#
# 0     [200.62,  95.45, 0.99]<br>
# 1     [210.18,  84.89, 0.97]<br>
# 2     [189.92,  86.53, 0.96] <br>
# 3     [226.54,  91.23, 0.80] <br>
# 4     [177.04,  95.76, 0.74] <br>
# 5     [251.49, 158.24, 0.99] <br>
# 6     [159.52, 160.88, 0.99]<br>
# 7     [274.91, 241.19, 0.98] <br>
# 8     [136.73, 243.06, 0.99] <br>
# 9     [269.69, 309.60, 0.98]<br>
# 10    [140.02, 309.99, 0.98] <br>
# 11    [231.35, 316.50, 0.99] <br>
# 12    [171.63, 316.26, 0.99]<br>
# 13    [234.20, 437.27, 0.99]<br>
# 14    [172.66, 434.59, 0.99] <br>
# 15    [231.90, 545.88, 0.98] <br>
# 16    [170.38, 542.04, 0.98]

# %% [markdown]
# - 0 - nose
# - 1 - left eye
# - 2 - right eye
# - 3 - left ear
# - 4 - right ear
# - 5 - left shoulder
# - 6 - right shoulder
# - 7 - left elbow
# - 8 - right elbow
# - 9 - left wrist
# - 10 - right wrist
# - 11 - left ilium
# - 12 - right ilium
# - 13 - left knee
# - 14 - right knee
# - 15 - left ankle
# - 16 - right ankle
#
#
# <br>
#
# - right side: even numbers
# - left side: odd numbers
